# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r"C:\Users\HP\EDA\dataset\Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
num_col=visa_df.select_dtypes(exclude="object").columns
num_col
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
plt.boxplot(visa_df["prevailing_wage"],vert=False)
plt.title("BOX PLOT")
plt.xlabel("wages")
plt.show()

# %%
plt.figure(figsize=(14,3))
plt.subplot(1,2,1)
plt.suptitle("Comparision of histogram with box plot")
plt.hist(visa_df["prevailing_wage"])
plt.xlabel("HISTOGRAM")
plt.subplot(1,2,2)
plt.boxplot(visa_df["prevailing_wage"],vert=False)
plt.xlabel("BOXPLOT")
plt.show()

# %%
plt.figure(figsize=(14,3))
plt.subplot(1,2,1).hist(visa_df["prevailing_wage"])
plt.suptitle("Comparision of histogram with box plot")
plt.xlabel("HISTOGRAM")
plt.subplot(1,2,2).boxplot(visa_df["prevailing_wage"],vert=False)
plt.xlabel("BOXPLOT")
plt.show()

# %%
#outliners in the given dataset

Q1=round(np.percentile(visa_df["prevailing_wage"],25))
Q2=round(np.percentile(visa_df["prevailing_wage"],50))
Q3=round(np.percentile(visa_df["prevailing_wage"],75))
IQR=Q3-Q1
LB=Q1-1.5*IQR
UB=Q3+1.5*IQR
con1=visa_df["prevailing_wage"]<LB
con2=visa_df["prevailing_wage"]>UB
con3=con1 | con2
outliners=visa_df[con3]
outliners[]
# Out:
#   Cell In[103], line 13
#     outliners[]
#               ^
# SyntaxError: invalid syntax

# %%
#NON outliners in the given dataset

Q1=round(np.percentile(visa_df["prevailing_wage"],25))
Q2=round(np.percentile(visa_df["prevailing_wage"],50))
Q3=round(np.percentile(visa_df["prevailing_wage"],75))
IQR=Q3-Q1
LB=Q1-1.5*IQR
UB=Q3+1.5*IQR
con1=visa_df["prevailing_wage"]>LB
con2=visa_df["prevailing_wage"]<UB
con3=con1 & con2
nonoutliners=visa_df[con3]
nonoutliners
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
x=nonoutliners["prevailing_wage"]
plt.figure(figsize=(14,3))
plt.suptitle("Comparision between hitogram and box plot")
plt.subplot(1,2,1).hist(x,bins=20)
plt.title("histogram")
plt.subplot(1,2,2).boxplot(x)
plt.title("box plot")
plt.show()

# %%
x=nonoutliners["prevailing_wage"]
plt.figure(figsize=(14,3))
plt.suptitle("Comparision between hitogram and box plot NON OUTLINERS")
plt.subplot(1,2,1).hist(x,bins=20)
plt.title("histogram")
plt.subplot(1,2,2).boxplot(x,vert=False)
plt.title("box plot")
plt.show()
#############################################
plt.figure(figsize=(14,3))
plt.subplot(1,2,1).hist(visa_df["prevailing_wage"],bins=20)
plt.suptitle("Comparision of histogram with box plot")
plt.xlabel("HISTOGRAM")
plt.subplot(1,2,2).boxplot(visa_df["prevailing_wage"],vert=False)
plt.xlabel("BOXPLOT")
plt.show()

# %%
wage_data_out=nonoutliners["prevailing_wage"]
wage_data=visa_df["prevailing_wage"]
##########################################
plt.figure(figsize=(10,8))
plt.hist(wage_data,bins=20)
plt.hist(wage_data_out,bins=20)
plt.show()

# %% [markdown]
# **how to deal outliers**
# 1. we can drop the outliers
#      - droping ourliers is an easy task, but not recommended
#    - if you drop the outliers we are dropping the rows
#    - which means we are deroping the other column values also
#    - may be some some important info in the other columns will be lost
#    -
#
# 2. Fill with median
#    - we already know that outliners doesnot affect median
#    - so it is the best practice to fill outliners with medain
#
# 4. Capping or flooring
#    - instead of fill with median
#    - we can fill with certain vlues
#    - the outliners which are less than lB fill with LB value
#    - th eoutliers which are greater than UB fill with UB value
#
# **Isolation forest**
# - is ML MOdel used to find the outliners and anamolies

# %%
nonoutliners["prevailing_wage"][2]
# Out:
# 122996.86

# %% [markdown]
# - In numpy we have method called where
# - it has 3 arguments
#       - condition
#       - value if condition is true
#       - value if condition is false
# - it is applicable for binary means if and else

# %%
list1=[]
wage_data=visa_df["prevailing_wage"]
for value in wage_data:
    if value<LB or value >UB:
        median=wage_data.median()
        list1.append(median)
    else:
        list1.append(value)

# %%
dict1={"Sub":['DS','DE','CS'],
         'marks':[100,200,300]}
df=pd.DataFrame(dict1)
df
# Out:
#   Sub  marks
# 0  DS    100
# 1  DE    200
# 2  CS    300

# %%
df
l=[]
for i in df["marks"]:
    if i>100:
        l.append(1)
    else:
        l.append(i)

df["marks"]=l
df
# Out:
#   Sub  marks
# 0  DS    100
# 1  DE      1
# 2  CS      1

# %%
dict1={"Sub":['DS','DE','CS'],
         'marks':[100,200,300]}
df=pd.DataFrame(dict1)
df
# Out:
#   Sub  marks
# 0  DS    100
# 1  DE    200
# 2  CS    300

# %%
#np.where (<condition>,<True>,<False>)
con=df["marks"]>100
l=np.where(con,1,df['marks'])
df["marks"]=l
df
# Out:
#   Sub  marks
# 0  DS    100
# 1  DE      1
# 2  CS      1

# %%
l=[]
wage_data=visa_df["prevailing_wage"]
med=wage_data.median()
con1=wage_data < LB 
con2= wage_data > UB
con3=con1 |con2
l=np.where(con3,med,wage_data)
l
visa_df["prevailing_wage_update"]=l

# %%
plt.subplot(1,2,1).boxplot(visa_df["prevailing_wage"])
plt.hist()
plt.subplot(1,2,2).boxplot(visa_df["prevailing_wage_update"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1bf03b7c5d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1bf03abb910>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1bf03b7e8d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1bf03c27910>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1bf03c24110>],
#  'means': []}
